# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr"],
    "Sales": [100, 150, 130, 180],
    "Profit": [90, 100, 110, 150]
})

# matplotlib
# plt.plot(df.Month, df.Sales)
# plt.show()

# Axes

# df.plot(x="Month", y="Sales")
# df.plot(x="Month", y=["Sales", "Profit"])

# %%
# Kind
# df.plot(x="Month", y="Sales", kind="bar")
# df.plot(x="Month", y="Profit", kind="scatter")
# df.plot(x="Month", y="Profit", kind="area")
df.plot(x="Month", y=["Profit", "Sales"], kind="line")
# plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(np.random.rand(100))
plt.show()
