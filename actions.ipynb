# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

print(pd.__version__)

# %%
df = pd.read_csv(r"./data/salary.csv")

# df.describe()

# df.info()

# df.head()

# df.tail()

# df.count()
df["City"].value_counts()

# %%
df.columns[0:3]
df[df.columns[0:3]]

# %%
df.loc[0:5, "Name":"City"]
df.iloc[0:5, 0:3]

# %%
df["Salary"]
df.Salary.sum()
df.Salary.mean()
df.Salary.median()

# %%
df.isnull()
df.isna()
df.notnull()

# %%
# df["Age"].fillna(0)

# df["Age"].mean()
# df["Age"].fillna(df["Age"].mean())

df.fillna({ "Age": 0, "City": "" })

# df.fillna({ "Age": 0, "City": "" }, inplace=True)
df

# %%
df.duplicated()
# df.drop_duplicates("Name", inplace=True)
# df.drop_duplicates(keep=False)
# df.drop_duplicates(keep="first")
df.drop_duplicates(keep="last")

# %%
# df.dropna(how="all")
df.dropna()

# %%
df["City"].replace("Bangalore", "Bengaluru")

# %%
# df.sort_values(["Age", "City"])
df.sort_index()
df.sort_values("Age")

# %%
orders = pd.read_csv(r"./data/orders.csv")
customers = pd.read_csv(r"./data/customers.csv")

# orders.merge(customers)

pd.merge(orders, customers, left_on="customer_id", right_on="customer_id", how="right")

# %%
df.groupby("City")["Salary"].mean()

# %%
df["City"].dropna().unique()

# %% [markdown]
# Sorting
# - By Index
# - By Value

# %% [markdown]
# Math
# - Min, Max
# - Sum, Mean, Median
# - Count

# %% [markdown]
# - Unique
# - Value Counts

# %% [markdown]
# Missing Values
# - isnull
# - notnull
# - dropna
# - fillna

# %% [markdown]
# Duplicates
# - drop duplicates
# - duplicated
#
# Replacing Values
# - replace

# %% [markdown]
# Merge

# %% [markdown]
# Group
# Agg
